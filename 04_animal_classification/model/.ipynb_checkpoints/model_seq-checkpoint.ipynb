# %%
#importing necessary library
import pandas as pd;
import tensorflow as tf;
from tensorflow import keras;
from keras import Sequential;
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten;
from tensorflow.keras.preprocessing.image import ImageDataGenerator;
from keras.applications.vgg16 import VGG16;
import matplotlib.pyplot as plt;
from tensorflow.keras.callbacks import EarlyStopping;

# %%
#applying data agumentation 
batch_size = 32
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True);

test_datagen = ImageDataGenerator(rescale=1./255);

train_generator = train_datagen.flow_from_directory(
        'dataset/train',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical');

validation_generator = test_datagen.flow_from_directory(
        'dataset/test',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical');
# Out:
# Found 1944 images belonging to 15 classes.
# Found 1944 images belonging to 15 classes.

# %%
#for transfer learning loading pre trained model
conv_base = VGG16(
    weights='imagenet',
    include_top = False, #remove fc layer
    input_shape=(150,150,3)
);

# %%
conv_base.summary();
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# preparing model layer
model = Sequential();
model.add(conv_base);
model.add(Flatten());
model.add(Dense(256,activation='relu'));
model.add(Dense(15,activation='softmax'));

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_4 (Flatten)         (None, 8192)              0
#
#  dense_8 (Dense)             (None, 256)               2097408
#
#  dense_9 (Dense)             (None, 15)                3855
#
# =================================================================
# Total params: 16,815,951
# Trainable params: 16,815,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling with binary crossentropy loss function
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy']);

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
);

# %%
history = model.fit_generator(
        train_generator,
        epochs=10,
        callbacks=callback,
        validation_data=validation_generator);
# Out:
# Epoch 1/10
# C:\Users\rupak\AppData\Local\Temp\ipykernel_17956\3659687957.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 61/61 [==============================] - 31s 506ms/step - loss: 2.7079 - accuracy: 0.0679 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 2/10
# 61/61 [==============================] - 31s 506ms/step - loss: 2.7079 - accuracy: 0.0694 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 3/10
# 61/61 [==============================] - 31s 507ms/step - loss: 2.7078 - accuracy: 0.0669 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 4/10
# 61/61 [==============================] - 31s 506ms/step - loss: 2.7080 - accuracy: 0.0653 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 5/10
# 61/61 [==============================] - 31s 506ms/step - loss: 2.7079 - accuracy: 0.0653 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 6/10
# 61/61 [==============================] - 31s 507ms/step - loss: 2.7079 - accuracy: 0.0669 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 7/10
# 61/61 [==============================] - 31s 507ms/step - loss: 2.7079 - accuracy: 0.0653 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 8/10
# 61/61 [==============================] - 31s 506ms/step - loss: 2.7079 - accuracy: 0.0705 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 9/10
# 61/61 [==============================] - 31s 506ms/step - loss: 2.7079 - accuracy: 0.0669 - val_loss: 2.7075 - val_accuracy: 0.0705
# Epoch 10/10
# 61/61 [==============================] - 31s 507ms/step - loss: 2.7080 - accuracy: 0.0633 - val_loss: 2.7075 - val_accuracy: 0.0705

# %%
plt.plot(history.history['accuracy'],color='red',label='train');
plt.plot(history.history['val_accuracy'],color='blue',label='validation');
plt.legend();
plt.show();

# %%
plt.plot(history.history['loss'],color='red',label='train');
plt.plot(history.history['val_loss'],color='blue',label='validation');
plt.legend();
plt.show();

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_bear = image.load_img(
    "bear.png",
    target_size=(150,150)
);

img_cat = image.load_img(
    "cat.png",
    target_size=(150,150)
);

# %%
img_array_bear = image.img_to_array(img_bear)
img_array_cat = image.img_to_array(img_cat)

# %%
img_array_bear = img_array_bear / 255.0
img_array_cat = img_array_cat / 255.0

# %%
img_array_bear = np.expand_dims(img_array_bear, axis=0)
img_array_cat = np.expand_dims(img_array_cat, axis=0)

# %%
prediction_bear = model.predict(img_array_bear)
prediction_cat = model.predict(img_array_cat)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
print("bear ",prediction_bear)
print("cat ",prediction_cat)
# Out:
# bear  [[0.06465705 0.07007156 0.06406725 0.06719071 0.06568437 0.06348801
#   0.06601188 0.06819385 0.06611027 0.06658773 0.06471334 0.06770664
#   0.06869914 0.06688087 0.06993731]]
# cat  [[0.06465705 0.07007156 0.06406725 0.06719071 0.06568437 0.06348801
#   0.06601188 0.06819385 0.06611027 0.06658773 0.06471334 0.06770664
#   0.06869914 0.06688087 0.06993731]]

# %%
train_generator.class_indices.keys()
# Out:
# dict_keys(['Bear', 'Bird', 'Cat', 'Cow', 'Deer', 'Dog', 'Dolphin', 'Elephant', 'Giraffe', 'Horse', 'Kangaroo', 'Lion', 'Panda', 'Tiger', 'Zebra'])

# %%
print(train_generator.class_indices)
# Out:
# {'Bear': 0, 'Bird': 1, 'Cat': 2, 'Cow': 3, 'Deer': 4, 'Dog': 5, 'Dolphin': 6, 'Elephant': 7, 'Giraffe': 8, 'Horse': 9, 'Kangaroo': 10, 'Lion': 11, 'Panda': 12, 'Tiger': 13, 'Zebra': 14}

# %%
predicted_index = np.argmax(prediction_bear)
class_labels = list(train_generator.class_indices.keys())
print(class_labels[predicted_index])
# Out:
# Bird

# %%
predicted_index = np.argmax(prediction_cat)
class_labels = list(train_generator.class_indices.keys())
print(class_labels[predicted_index])
# Out:
# Bird
